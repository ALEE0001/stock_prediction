# %%
import pandas as pd
import numpy as np
import requests
from io import BytesIO
import time
from datetime import date, datetime, timedelta
import random
import os

# %%
# Import packages
import yfinance as yf

# Read and print the stock tickers that make up S&P500
df_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
df_tickers = df_tickers.rename(columns={'Symbol':'ticker'})
# Make sure GOOG and GOOGL are not both included
df_tickers = df_tickers[df_tickers['ticker'] != 'GOOG']

try:
    df_available = pd.read_csv('data/data.csv')
    df_tickers = df_tickers[~df_tickers['ticker'].isin(df_available['ticker'])]
except:
    pass

random.seed(1993)
# Get stratified random 17 samples per sector
# df_tickers_sample = df_tickers.groupby('GICS Sector', group_keys=False).apply(lambda x: x.sample(17))
df_tickers_sample = df_tickers.sample(230)

tickers = list(df_tickers_sample['ticker'])

# Custom Tickers
# tickers.extend(['BTC/USD', 'ETH/USD', 'XRP/USD', 'LTC/USD', 'ADA/USD', 'MATIC/USD'])
# Out:
# C:\Users\18327\AppData\Local\Temp\ipykernel_8980\2910404954.py:11: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_available = pd.read_csv('data/data.csv')

# %%
# Twelve Data
api_key = twelve_data_api

data_frames = []

for ticker in tickers:
        
    try:
        # Get Earliest Date
        url = f'https://api.twelvedata.com/earliest_timestamp?symbol={ticker}&interval=1day&apikey={api_key}'
        r = requests.get(url)
        
        start_date = r.text.split('"')[3]
        end_date = date.today().strftime('%Y-%m-%d')
        total_days = (pd.to_datetime(end_date) - pd.to_datetime(start_date)).days
        
        batch_size = np.ceil(total_days / 5000).astype(int)
        
        l_dates = []      
        
        # If multiple batches, append start and end dates for every 5000 days
        if batch_size > 1:  
            for i in range(batch_size-1):
                l_dates.append((pd.to_datetime(end_date)  - timedelta(days=(5000 * i))).strftime('%Y-%m-%d'))
            l_dates.append(start_date)
        else:
            l_dates.append(end_date)
            l_dates.append(start_date)
        
        # Check how many credits are left, and pause for 60 seconds to reset Twelve Data's limit
        api_credit = r.headers['Api-Credits-Left']
        if api_credit == '0':
            time.sleep(61)
        
        for i in range(batch_size):
            try:
                batch_end = l_dates[i]
                batch_start = l_dates[i+1]
                
                # Make sure date range don't overlap throughout the loop
                if (i > 0):
                    batch_end = (pd.to_datetime(batch_end) - timedelta(days=1)).strftime('%Y-%m-%d')
                
                url = f'https://api.twelvedata.com/time_series?&start_date={batch_start}&end_date={batch_end}&symbol={ticker}&format=CSV&interval=1day&apikey={api_key}'
                r = requests.get(url)

                # Decode bytes into a string
                data_string = r.content.decode('utf-8')

                # Use StringIO to treat the string as a file-like object
                data_file = BytesIO(data_string.encode())
                
                # Union the new data to data from previous iteration. 
                data = pd.read_csv(data_file, delimiter=';')
                data['ticker'] = ticker
                
                # Append data to list
                data_frames.append(data)
                
                # Check how many credits are left, and pause for 60 seconds to reset Twelve Data's limit
                api_credit = r.headers['Api-Credits-Left']
                if api_credit == '0':
                    time.sleep(61)
                
            except:
                pass
        
        print(data_frames[-1])

    except:
        print(f"Couldn't download {ticker}.")

df_final = pd.concat([i for i in data_frames if len(i) > 0])

merge_cols = ['GICS Sector', 'GICS Sub-Industry', 'Headquarters Location', 'Date added', 'Founded'] # 'CIK'
df_model = df_final.merge(df_tickers, on='ticker', how='left')

# Only save tickers with 5 years or more data
ticker_days = df_model.groupby('ticker')['ticker'].value_counts().reset_index()
five_yrs_more = ticker_days[ticker_days['count'] >= 1825]['ticker']
df_model = df_model[df_model['ticker'].isin(five_yrs_more)]

df_model.to_csv(f'data/raw/{datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.csv', index=False)
# Out:
#         datetime   open      high       low     close  volume ticker
# 0     1996-12-02  19.15  19.15000  18.85000  19.07000  217200    EFX
# 1     1996-11-29  19.07  19.29000  19.07000  19.15000  127400    EFX
# 2     1996-11-27  19.36  19.80000  19.00000  19.00000  392700    EFX
# 3     1996-11-26  19.29  19.51000  19.22000  19.36000  194000    EFX
# 4     1996-11-25  18.71  19.51000  18.41000  19.36000  481100    EFX
# ...          ...    ...       ...       ...       ...     ...    ...
# 4202  1980-03-21   0.43   0.44000   0.43000   0.43000   12000    EFX
# 4203  1980-03-20   0.44   0.44000   0.44000   0.44000    2400    EFX
# 4204  1980-03-18   0.44   0.44000   0.44000   0.44000   19200    EFX
# 4205  1980-03-17   0.45   0.45000   0.44000   0.45000   57600    EFX
# 4206  1980-03-17   0.00   0.77604   0.76042   0.76562   57600    EFX
#
# [4207 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  15.17000  15.24000  15.09000  15.20000  1962000    AXP
# 1     1996-11-29  15.42000  15.42000  15.31000  15.31000   642300    AXP
# 2     1996-11-27  15.57000  15.57000  15.28000  15.39000  2736000    AXP
# 3     1996-11-26  15.42000  15.83000  15.39000  15.53000  5562900    AXP
# 4     1996-11-25  15.13000  15.42000  15.13000  15.39000  4399200    AXP
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-02-28   2.32540   2.34954   2.31736   2.31736  1051715    AXP
# 4996  1977-02-25   2.32540   2.35759   2.32540   2.32540  1318916    AXP
# 4997  1977-02-24   2.35759   2.35759   2.32540   2.32540  1741467    AXP
# 4998  1977-02-23   2.39782   2.43001   2.39782   2.39782  1121623    AXP
# 4999  1977-02-22   2.39782   2.41391   2.37368   2.37368   930543    AXP
#
# [5000 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  22.31000  22.38000  21.94000  22.00000  1422000     DE
# 1     1996-11-29  22.50000  22.56000  22.31000  22.31000   472600     DE
# 2     1996-11-27  22.06000  22.56000  21.94000  22.50000  2505200     DE
# 3     1996-11-26  22.31000  23.00000  21.56000  22.00000  5804400     DE
# 4     1996-11-25  23.25000  23.44000  22.81000  23.31000  2022000     DE
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-03   4.68750   4.72917   4.64583   4.72917  1812600     DE
# 4996  1977-03-02   4.68750   4.72917   4.68750   4.68750   458400     DE
# 4997  1977-03-01   4.66667   4.68750   4.62500   4.66667   331200     DE
# 4998  1977-02-28   4.66667   4.68750   4.62500   4.66667   291000     DE
# 4999  1977-02-25   4.70833   4.70833   4.62500   4.66667   324600     DE
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     2024-04-19  83.77  84.29  82.31  82.46  2882800    STX
# 1     2024-04-18  83.79  85.20  83.31  83.44  1811700    STX
# 2     2024-04-17  84.95  86.30  84.04  84.20  3465900    STX
# 3     2024-04-16  83.54  84.71  83.02  83.68  2454000    STX
# 4     2024-04-15  86.68  87.10  83.30  83.88  2925200    STX
# ...          ...    ...    ...    ...    ...      ...    ...
# 4995  2004-06-17  13.85  14.00  13.62  13.95  3064400    STX
# 4996  2004-06-16  13.85  13.98  13.81  13.85  1713200    STX
# 4997  2004-06-15  13.73  13.98  13.71  13.90  2198500    STX
# 4998  2004-06-14  13.57  13.79  13.41  13.61  3003600    STX
# 4999  2004-06-10  13.45  13.92  13.42  13.57  4299300    STX
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     1996-12-02  15.37  15.44  14.96  15.33   908400      L
# 1     1996-11-29  15.50  15.52  15.46  15.46   741600      L
# 2     1996-11-27  15.35  15.46  15.31  15.46  2677202      L
# 3     1996-11-26  15.73  15.73  15.25  15.35  2609402      L
# 4     1996-11-25  15.17  15.79  15.15  15.77  1532401      L
# ...          ...    ...    ...    ...    ...      ...    ...
# 4220  1980-03-19   0.69   0.69   0.68   0.69  1872001      L
# 4221  1980-03-18   0.67   0.67   0.66   0.67   855000      L
# 4222  1980-03-17   0.67   0.68   0.67   0.67  1044001      L
# 4223  1970-01-01  51.08  51.11  51.08  51.09   108360      L
# 4224  1969-12-31  51.08  51.11  51.08  51.09   108360      L
#
# [4225 rows x 7 columns]
#         datetime   open   high    low  close    volume ticker
# 0     2024-04-19  51.19  53.10  50.90  51.38  16351200    UAL
# 1     2024-04-18  49.22  51.88  49.20  51.42  38676000    UAL
# 2     2024-04-17  44.45  49.14  44.11  48.74  67541300    UAL
# 3     2024-04-16  40.80  41.72  40.10  41.50  18510900    UAL
# 4     2024-04-15  42.15  42.83  40.84  41.04  10452100    UAL
# ...          ...    ...    ...    ...    ...       ...    ...
# 4578  2006-02-09  29.80  34.98  29.51  34.50   8016600    UAL
# 4579  2006-02-08  31.46  32.40  30.88  32.00   8960500    UAL
# 4580  2006-02-07  33.90  33.90  31.73  32.99   3224600    UAL
# 4581  2006-02-06  34.82  34.94  33.70  33.90   1940300    UAL
# 4582  2006-02-06  34.82  34.94  33.70  33.90   1940300    UAL
#
# [4583 rows x 7 columns]
#         datetime       open       high        low      close   volume ticker
# 0     2024-04-19  143.14999  144.12000  142.55000  142.77000  5118500    UPS
# 1     2024-04-18  143.08000  143.31000  141.88000  142.74001  3430600    UPS
# 2     2024-04-17  142.50000  143.42000  141.35001  142.25000  4165700    UPS
# 3     2024-04-16  144.53999  144.71001  142.71001  142.89000  4197100    UPS
# 4     2024-04-15  145.87000  146.53999  143.42999  144.85001  3271000    UPS
# ...          ...        ...        ...        ...        ...      ...    ...
# 4995  2004-06-16   73.23000   73.29000   72.66000   73.14000  1564200    UPS
# 4996  2004-06-15   73.05000   73.50000   72.83000   73.14000  2211600    UPS
# 4997  2004-06-14   72.63000   73.21000   72.61000   72.87000  1530600    UPS
# 4998  2004-06-10   72.80000   73.42000   72.80000   73.19000  1662100    UPS
# 4999  2004-06-09   73.08000   73.25000   72.72000   72.74000  1463400    UPS
#
# [5000 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     2010-08-11  31.23062  31.85077  31.22093  31.40504  1107233      O
# 1     2010-08-10  31.47287  32.05426  31.46318  31.71512   832514      O
# 2     2010-08-09  31.56977  31.87016  31.34690  31.77326   478745      O
# 3     2010-08-06  30.83333  31.49225  30.83333  31.38566   509086      O
# 4     2010-08-05  31.56977  31.70543  31.25969  31.27907   489168      O
# ...          ...       ...       ...       ...       ...      ...    ...
# 3978  1994-10-24   8.35756   8.53924   8.17587   8.17587    75749      O
# 3979  1994-10-21   8.47868   8.53924   8.29700   8.35756    68731      O
# 3980  1994-10-20   8.53924   8.78149   8.47868   8.47868   141590      O
# 3981  1994-10-19   7.81250   8.47868   7.81250   8.41812   249950      O
# 3982  1994-10-18   7.75194   7.81250   7.63081   7.75194   418166      O
#
# [3983 rows x 7 columns]
#         datetime   open   high    low  close     volume ticker
# 0     2010-08-11  24.68  24.90  24.56  24.86   76745824   MSFT
# 1     2010-08-10  25.33  25.34  24.88  25.07   87257680   MSFT
# 2     2010-08-09  25.55  25.73  25.37  25.61   57102544   MSFT
# 3     2010-08-06  25.18  25.56  25.02  25.55   55985488   MSFT
# 4     2010-08-05  25.49  25.58  25.21  25.37   64922012   MSFT
# ...          ...    ...    ...    ...    ...        ...    ...
# 4995  1990-10-16   0.76   0.80   0.75   0.76  300888000   MSFT
# 4996  1990-10-15   0.78   0.81   0.77   0.78  130334400   MSFT
# 4997  1990-10-12   0.79   0.82   0.75   0.79  109252800   MSFT
# 4998  1990-10-11   0.81   0.84   0.79   0.81   83815200   MSFT
# 4999  1990-10-10   0.83   0.86   0.82   0.83  115596000   MSFT
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     2024-04-19  48.75  49.31  48.63  49.12  1506400    LKQ
# 1     2024-04-18  48.38  48.97  48.21  48.58  1640000    LKQ
# 2     2024-04-17  48.96  49.00  47.85  47.91  1111000    LKQ
# 3     2024-04-16  48.76  48.90  48.42  48.44  1422100    LKQ
# 4     2024-04-15  49.90  50.13  48.99  49.03  1060800    LKQ
# ...          ...    ...    ...    ...    ...      ...    ...
# 4995  2004-06-17   2.27   2.32   2.27   2.32  1493488    LKQ
# 4996  2004-06-16   2.31   2.32   2.31   2.31   953232    LKQ
# 4997  2004-06-15   2.28   2.31   2.28   2.31   394576    LKQ
# 4998  2004-06-14   2.31   2.31   2.25   2.31   187560    LKQ
# 4999  2004-06-10   2.32   2.32   2.28   2.30   329984    LKQ
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close    volume ticker
# 0     2010-08-11  53.57  53.70  52.42  52.43   1796950     CB
# 1     2010-08-10  53.65  54.47  53.59  54.16   1773358     CB
# 2     2010-08-09  53.54  54.24  53.52  54.20   1540063     CB
# 3     2010-08-06  53.44  53.56  52.64  53.56   2107855     CB
# 4     2010-08-05  54.11  54.31  53.65  53.74   1514629     CB
# ...          ...    ...    ...    ...    ...       ...    ...
# 4375  1993-03-30   9.42   9.46   9.33   9.46   2520902     CB
# 4376  1993-03-29   9.50   9.58   9.42   9.46   2249402     CB
# 4377  1993-03-26   9.54   9.71   9.50   9.58   5826006     CB
# 4378  1993-03-25   9.67   9.71   9.46   9.54  20047520     CB
# 4379  1993-03-25   9.67   9.71   9.46   9.54  20047520     CB
#
# [4380 rows x 7 columns]
#         datetime      open      high     low     close   volume ticker
# 0     1996-12-02  14.25000  14.31000  14.120  14.19000   404400    PEG
# 1     1996-11-29  14.31000  14.31000  14.250  14.31000   204800    PEG
# 2     1996-11-27  14.31000  14.31000  14.190  14.25000   307800    PEG
# 3     1996-11-26  14.44000  14.44000  14.250  14.25000  1142800    PEG
# 4     1996-11-25  14.38000  14.44000  14.310  14.44000   388800    PEG
# ...          ...       ...       ...     ...       ...      ...    ...
# 4275  1980-01-07   6.45833   6.45833   6.375   6.45833    36600    PEG
# 4276  1980-01-04   6.41667   6.45833   6.375   6.45833    41100    PEG
# 4277  1980-01-03   6.37500   6.45833   6.375   6.41667    82500    PEG
# 4278  1980-01-02   6.37500   6.45833   6.375   6.37500    61800    PEG
# 4279  1980-01-02   6.37500   6.45833   6.375   6.37500    61800    PEG
#
# [4280 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     2024-04-19  80.19000  80.53000  79.31000  79.49000  2406400    FTV
# 1     2024-04-18  80.50000  81.16000  80.05000  80.18000  1518500    FTV
# 2     2024-04-17  80.71000  80.95000  79.67000  80.20000  1866000    FTV
# 3     2024-04-16  81.60000  81.60000  80.79000  81.04000  1012500    FTV
# 4     2024-04-15  83.24000  83.66000  81.25500  81.60000  1553400    FTV
# ...          ...       ...       ...       ...       ...      ...    ...
# 1957  2016-07-11  41.17992  42.87029  40.98745  42.77824  7220549    FTV
# 1958  2016-07-08  40.13389  42.35146  39.77406  42.00837  5070983    FTV
# 1959  2016-07-07  39.84937  40.16736  39.61925  39.94979  6556726    FTV
# 1960  2016-07-06  39.38912  40.66946  38.73640  39.95816  8014268    FTV
# 1961  2016-07-05  41.33891  45.47280  40.49791  40.66946  7445687    FTV
#
# [1962 rows x 7 columns]
#         datetime       open       high        low      close   volume ticker
# 0     2024-04-19  414.32001  417.92001  411.60999  417.01001  1159100    AMP
# 1     2024-04-18  413.67001  416.42001  410.54001  412.63000   365800    AMP
# 2     2024-04-17  414.07001  416.26999  411.20999  411.76999   518300    AMP
# 3     2024-04-16  411.42001  413.97000  408.76999  410.85001   583200    AMP
# 4     2024-04-15  420.34000  423.54999  409.19000  411.17999   589000    AMP
# ...          ...        ...        ...        ...        ...      ...    ...
# 4675  2005-09-21   36.60000   36.60000   36.00000   36.40000   424300    AMP
# 4676  2005-09-20   36.60000   37.00000   36.60000   36.70000   654900    AMP
# 4677  2005-09-19   36.60000   36.70000   36.45000   36.70000  1162300    AMP
# 4678  2005-09-16   37.00000   37.00000   36.60000   36.60000    62400    AMP
# 4679  2005-09-15   38.02000   38.10000   37.00000   37.01000  1529800    AMP
#
# [4680 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     2024-04-19  40.48  41.08  40.40  40.62  3467500    TPR
# 1     2024-04-18  40.84  41.07  40.09  40.50  3814500    TPR
# 2     2024-04-17  41.35  41.55  40.22  40.49  4344200    TPR
# 3     2024-04-16  40.53  40.95  39.98  40.86  4288000    TPR
# 4     2024-04-15  41.92  42.32  40.59  40.83  3084400    TPR
# ...          ...    ...    ...    ...    ...      ...    ...
# 4995  2004-06-16  21.62  21.82  21.41  21.70  2336800    TPR
# 4996  2004-06-15  22.09  22.10  21.45  21.55  3648400    TPR
# 4997  2004-06-14  22.80  22.80  22.04  22.06  2275000    TPR
# 4998  2004-06-10  22.55  22.90  22.48  22.85  2277000    TPR
# 4999  2004-06-09  22.49  22.59  22.36  22.49  2417000    TPR
#
# [5000 rows x 7 columns]
#      datetime   open   high    low  close  volume ticker
# 0  1970-01-01  89.97  89.97  89.87  89.87  134988    AME
#         datetime   open   high    low  close     volume ticker
# 0     2010-08-11  39.20  39.44  38.44  39.36   21456288   QCOM
# 1     2010-08-10  39.50  40.00  39.08  39.78   17161710   QCOM
# 2     2010-08-09  38.87  39.94  38.83  39.75   18716768   QCOM
# 3     2010-08-06  38.20  38.98  37.95  38.65   15795059   QCOM
# 4     2010-08-05  38.21  38.70  38.12  38.50    8991875   QCOM
# ...          ...    ...    ...    ...    ...        ...    ...
# 4697  1991-12-19   0.57   0.57   0.55   0.55    7299200   QCOM
# 4698  1991-12-18   0.57   0.57   0.55   0.57   10899200   QCOM
# 4699  1991-12-17   0.57   0.58   0.55   0.55   16176000   QCOM
# 4700  1991-12-16   0.56   0.58   0.54   0.55   22585600   QCOM
# 4701  1991-12-13   0.53   0.59   0.52   0.56  143667200   QCOM
#
# [4702 rows x 7 columns]
#         datetime    open    high     low   close   volume ticker
# 0     2024-04-19  68.000  68.750  67.870  68.340  1824400    KMX
# 1     2024-04-18  68.830  69.670  67.720  67.910  2508400    KMX
# 2     2024-04-17  69.990  70.250  68.510  68.530  2110200    KMX
# 3     2024-04-16  69.570  70.140  68.920  69.800  3049300    KMX
# 4     2024-04-15  71.060  71.930  69.020  69.460  3638000    KMX
# ...          ...     ...     ...     ...     ...      ...    ...
# 4995  2004-06-16  10.975  11.000  10.795  10.800  3244000    KMX
# 4996  2004-06-15  11.350  11.400  11.125  11.160  2041800    KMX
# 4997  2004-06-14  11.255  11.410  11.185  11.185  2912800    KMX
# 4998  2004-06-10  11.570  11.590  11.250  11.250  2602400    KMX
# 4999  2004-06-09  11.230  11.895  11.225  11.570  6923400    KMX
#
# [5000 rows x 7 columns]
#         datetime     open     high      low    close   volume ticker
# 0     1996-12-02  27.2500  29.3750  27.1875  29.3125  2455200    WDC
# 1     1996-11-29  26.9375  27.0000  26.7500  26.8750   174400    WDC
# 4999  2004-06-09  32.21  32.38  31.85  31.87  1606600    MET
#
# [5000 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  15.06000  15.44000  15.03000  15.41000  2610400    HAL
# 1     1996-11-29  15.06000  15.09000  15.03000  15.06000   340000    HAL
# 2     1996-11-27  15.22000  15.34000  14.97000  15.03000  1673600    HAL
# 3     1996-11-26  15.84000  15.88000  14.84000  15.16000  3366000    HAL
# 4     1996-11-25  15.59000  15.91000  15.56000  15.69000  3002800    HAL
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-02   6.79020   6.79020   6.68596   6.70085   478400    HAL
# 4996  1977-03-01   6.64129   6.79020   6.64129   6.79020   401200    HAL
# 4997  1977-02-28   6.64129   6.64129   6.53705   6.61151   818400    HAL
# 4998  1977-02-25   6.58173   6.67107   6.58173   6.62640   397600    HAL
# 4999  1977-02-24   6.64129   6.67107   6.55194   6.58173   410400    HAL
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     1996-12-02  26.06  26.56  25.75  26.56  1780800    KEY
# 1     1996-11-29  26.19  26.38  26.12  26.19   717800    KEY
# 2     1996-11-27  25.62  26.44  25.56  26.38  2350200    KEY
# 3     1996-11-26  25.69  25.81  25.25  25.25  1318200    KEY
# 4     1996-11-25  25.12  25.62  24.94  25.62  1455000    KEY
# ...          ...    ...    ...    ...    ...      ...    ...
# 4219  1980-03-19   1.94   2.03   1.94   1.94     8000    KEY
# 4220  1980-03-18   1.94   2.03   1.94   1.94    36800    KEY
# 4221  1980-03-17   1.94   2.03   1.94   1.94    97600    KEY
# 4222  1980-03-17   1.94   2.03   1.94   1.94    97600    KEY
# 4223  1980-03-16   1.94   2.03   1.94   1.94    97600    KEY
#
# [4224 rows x 7 columns]
#         datetime   open   high    low  close  volume ticker
# 0     1996-12-02   1.90   1.91   1.89   1.90  181199    CHD
# 1     1996-11-29   1.88   1.89   1.88   1.88   85199    CHD
# 2     1996-11-27   1.88   1.89   1.86   1.88  122399    CHD
# 3     1996-11-26   1.88   1.89   1.85   1.85  194399    CHD
# 4     1996-11-25   1.88   1.91   1.88   1.88  217198    CHD
# ...          ...    ...    ...    ...    ...     ...    ...
# 4058  1980-03-24   0.17   0.19   0.17   0.17   48599    CHD
# 4059  1980-03-21   0.17   0.19   0.17   0.17   32399    CHD
# 4060  1980-03-18   0.17   0.19   0.17   0.17   80999    CHD
# 4061  1980-03-17   0.17   0.19   0.17   0.17  113399    CHD
# 4062  1970-01-01  72.86  72.86  72.77  72.78  443354    CHD
#
# [4063 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  33.38000  33.56000  33.06000  33.50000  2081600    CVX
# 1     1996-11-29  33.44000  33.56000  33.38000  33.50000   644200    CVX
# 2     1996-11-27  33.94000  34.00000  33.19000  33.31000  1916000    CVX
# 3     1996-11-26  33.94000  34.19000  33.75000  34.06000  1924200    CVX
# 4     1996-11-25  33.81000  34.19000  33.62000  33.88000  2725600    CVX
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-03   5.03125   5.12500   5.03125   5.10938   703200    CVX
# 4996  1977-03-02   5.04688   5.06250   5.01562   5.03125   440000    CVX
# 4997  1977-03-01   5.01562   5.07812   5.00000   5.04688   872800    CVX
# 4998  1977-02-28   5.00000   5.01562   4.98438   5.01562   364800    CVX
# 4999  1977-02-25   4.98438   5.01562   4.95312   5.00000   539200    CVX
#
# [5000 rows x 7 columns]
#         datetime   open   high      low    close   volume ticker
# 0     1996-12-02   2.78   2.83   2.7800   2.8100   816000   EXPD
# 1     1996-11-29   2.81   2.81   2.7700   2.7800   196800   EXPD
# 2     1996-11-27   2.83   2.86   2.7700   2.8100   902400   EXPD
# 3     1996-11-26   2.78   2.88   2.7800   2.8000  1889600   EXPD
# 4     1996-11-25   2.75   2.83   2.7200   2.8300  2569600   EXPD
# ...          ...    ...    ...      ...      ...      ...    ...
# 2993  1984-10-01   0.17   0.17   0.1700   0.1700   240000   EXPD
# 2994  1984-09-28   0.17   0.18   0.1700   0.1700   201600   EXPD
# 2995  1984-09-27   0.17   0.18   0.1700   0.1700   240000   EXPD
# 2996  1984-09-26   0.17   0.18   0.1700   0.1700   600000   EXPD
# 2997  1970-01-01  49.18  49.44  49.0111  49.3291    63825   EXPD
#
# [2998 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  20.48780  20.79268  20.48780  20.67073   931520    BDX
# 1     1996-11-29  20.48780  20.79268  20.48780  20.48780   535460    BDX
# 2     1996-11-27  20.12195  20.54878  19.87805  20.48780  1132010    BDX
# 3     1996-11-26  19.63415  20.12195  19.57317  20.00000  1620115    BDX
# 4     1996-11-25  19.26829  19.87805  19.02439  19.63415  3217885    BDX
# ...          ...       ...       ...       ...       ...      ...    ...
# 3455  1978-01-20   2.00457   2.00457   2.00457   2.00457        0    BDX
# 3456  1978-01-19   2.00457   2.00457   2.00457   2.00457        0    BDX
# 3457  1978-01-18   2.00457   2.00457   2.00457   2.00457        0    BDX
# 3458  1978-01-17   2.00457   2.00457   2.00457   2.00457        0    BDX
# 3459  1975-04-11   2.17226   2.17226   2.17226   2.17226        0    BDX
#
# [3460 rows x 7 columns]
#         datetime        open        high         low       close  volume  \
# 0     2024-04-19  1201.65002  1202.30005  1185.87000  1188.54004  100800
# 1     2024-04-18  1175.00000  1206.12000  1142.91003  1192.56006  167000
# 2     2024-04-17  1235.28003  1235.28003  1196.81995  1198.03003  150800
# 3     2024-04-16  1242.71997  1242.71997  1223.51001  1228.30005  105200
# 4     2024-04-15  1277.31995  1277.31995  1239.47998  1243.56006   94600
# ...          ...         ...         ...         ...         ...     ...
# 4995  2004-06-16    48.74000    49.16000    48.69000    49.10000  138000
# 4996  2004-06-15    48.17000    48.95000    48.16000    48.64000  198700
# 4997  2004-06-14    47.65000    48.49000    47.65000    48.17000  246100
# 4998  2004-06-10    47.99000    48.32000    47.99000    48.11000  109300
# 4999  2004-06-09    48.03000    48.28000    47.98000    48.09000  196800
#
#      ticker
# 0       MTD
# 1       MTD
# 2       MTD
# 3       MTD
# 4       MTD
# ...     ...
# 4995    MTD
# 4996    MTD
# 4997    MTD
# 4998    MTD
# 4999    MTD
#
# [5000 rows x 7 columns]
#         datetime    open    high     low   close  volume ticker
# 0     1996-12-02    7.16    7.25    7.16    7.25   35200    WST
# 1     1996-11-29    7.09    7.16    7.09    7.16   10400    WST
# 2     1996-11-27    7.03    7.06    7.03    7.06   17200    WST
# 3     1996-11-26    6.97    7.09    6.97    7.00  165200    WST
# 4     1996-11-25    6.94    7.00    6.94    7.00   20000    WST
# ...          ...     ...     ...     ...     ...     ...    ...
# 4191  1980-03-19    0.78    0.83    0.78    0.78   22400    WST
# 4192  1980-03-18    0.77    0.81    0.77    0.77   28800    WST
# 4193  1980-03-17    0.78    0.83    0.78    0.78   48000    WST
# 4194  1970-01-01  141.91  141.92  141.91  141.92   64781    WST
# 4195  1969-12-31  141.91  141.92  141.91  141.92   64781    WST
#
# [4196 rows x 7 columns]
#         datetime    open    high     low   close   volume ticker
# 0     1996-12-02   18.88   18.92   18.75   18.90   666600    MMC
# 1     1996-11-29   18.94   18.98   18.90   18.90   232200    MMC
# 2     1996-11-27   19.06   19.15   18.83   18.94   531600    MMC
# 3     1996-11-26   18.83   19.04   18.81   19.02  1054800    MMC
# 4     1996-11-25   18.77   18.88   18.63   18.83  1338000    MMC
# ...          ...     ...     ...     ...     ...      ...    ...
# 4224  1980-03-19    2.40    2.44    2.39    2.40   211200    MMC
# 4225  1980-03-18    2.43    2.45    2.41    2.43   172800    MMC
# 4226  1980-03-17    2.47    2.49    2.47    2.47  1533600    MMC
# 4227  1970-01-01  101.15  101.26  101.15  101.25   235308    MMC
# 4228  1970-01-01  101.15  101.26  101.15  101.25   235308    MMC
#
# [4229 rows x 7 columns]
#         datetime       open       high        low      close   volume ticker
# 0     2024-04-19  165.28999  167.10001  162.11000  166.25000   844700   PODD
# 1     2024-04-18  166.44000  169.24001  163.85001  164.73000   589100   PODD
# 2     2024-04-17  172.71001  173.74001  165.10001  166.25999   688800   PODD
# 3     2024-04-16  172.87000  174.82001  168.05000  172.71001   656000   PODD
# 4     2024-04-15  176.42000  178.42000  173.81000  173.94000   818300   PODD
# ...          ...        ...        ...        ...        ...      ...    ...
# 4258  2007-05-21   15.23000   15.63000   15.10000   15.63000   157200   PODD
# 4259  2007-05-18   15.05000   15.29000   15.05000   15.18000   140600   PODD
# 4260  2007-05-17   15.29000   15.59000   15.05000   15.13000   426700   PODD
# 4261  2007-05-16   15.95000   15.97000   15.03000   15.45000   357600   PODD
# 4262  2007-05-15   17.00000   17.00000   15.77000   15.96000  4850000   PODD
#
# [4263 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     2010-08-11  15.05  15.05  14.64  14.66  9553508   SCHW
# 1     2010-08-10  15.36  15.37  15.10  15.22  9808665   SCHW
# 2     2010-08-09  15.31  15.46  15.18  15.43  6278817   SCHW
# 3     2010-08-06  15.31  15.49  15.13  15.28  9398215   SCHW
#
# [2522 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  10.99355  11.01322  10.80672  11.01322  5745824    RTX
# 1     1996-11-29  10.99355  11.08205  10.99355  11.03288  1445354    RTX
# 2     1996-11-27  10.96405  11.05255  10.93455  10.99355  4119959    RTX
# 3     1996-11-26  10.89522  11.00338  10.78705  10.85588  4775898    RTX
# 4     1996-11-25  10.91488  10.95422  10.80672  10.89522  7324654    RTX
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-01   1.40123   1.41598   1.39632   1.41598  1296624    RTX
# 4996  1977-02-28   1.39632   1.40123   1.38648   1.40123  1161877    RTX
# 4997  1977-02-25   1.38157   1.39632   1.37665   1.39632   635600    RTX
# 4998  1977-02-24   1.38648   1.39140   1.37665   1.38157   808483    RTX
# 4999  1977-02-23   1.37665   1.38648   1.37173   1.38648  2872912    RTX
#
# [5000 rows x 7 columns]
#         datetime   open      high       low     close  volume ticker
# 0     1996-12-02  24.62  24.88000  24.44000  24.88000  366200    HSY
# 1     1996-11-29  25.06  25.06000  24.94000  24.94000  239800    HSY
# 2     1996-11-27  25.44  25.44000  24.94000  25.00000  529600    HSY
# 3     1996-11-26  25.50  25.69000  25.38000  25.56000  431200    HSY
# 4     1996-11-25  25.12  25.62000  25.00000  25.38000  594200    HSY
# ...          ...    ...       ...       ...       ...     ...    ...
# 4223  1980-03-20   0.86   0.87000   0.85000   0.86000   26400    HSY
# 4224  1980-03-19   0.86   0.87000   0.86000   0.86000  108000    HSY
# 4225  1980-03-18   0.85   0.85000   0.84000   0.85000   67200    HSY
# 4226  1980-03-17   0.84   0.89000   0.84000   0.84000   96000    HSY
# 4227  1980-03-17   0.00   0.88542   0.84375   0.84375   96000    HSY
#
# [4228 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  49.50000  49.50000  48.75000  48.75000  1671600     BA
# 1     1996-11-29  49.81250  49.93750  49.68750  49.68750   509800     BA
# 2     1996-11-27  49.62500  50.18750  49.62500  49.81250  1668600     BA
# 3     1996-11-26  49.31250  50.12500  49.25000  49.62500  3076000     BA
# 4     1996-11-25  49.31250  49.43750  49.06250  49.31250  1896000     BA
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-01   1.38272   1.43621   1.38272   1.43621  1366875     BA
# 4996  1977-02-28   1.37449   1.38272   1.37037   1.38272   738113     BA
# 4997  1977-02-25   1.36626   1.37860   1.36626   1.37449   786713     BA
# 4998  1977-02-24   1.39095   1.39095   1.36626   1.36626  1858950     BA
# 4999  1977-02-23   1.36214   1.41564   1.36214   1.39095  3213675     BA
#
# [5000 rows x 7 columns]
#         datetime    open       high        low      close    volume ticker
# 0     2024-04-19  179.42  179.70000  174.14000  175.03999   3249900   FSLR
# 1     2024-04-18  178.48  179.07001  173.19000  174.28999   1633900   FSLR
# 2     2024-04-17  175.53  183.64999  172.41000  178.00999   3343000   FSLR
# 3     2024-04-16  174.22  175.66000  172.00999  173.08000   1856200   FSLR
# 4     2024-04-15  181.38  182.00000  175.87000  175.96001   1614500   FSLR
# ...          ...     ...        ...        ...        ...       ...    ...
# 4379  2006-11-22   24.57   26.88000   24.50000   26.88000   1260800   FSLR
# 4380  2006-11-21   25.00   25.19000   24.31000   24.60000   1179900   FSLR
# 4381  2006-11-20   24.69   25.67000   24.29000   25.00000   1689000   FSLR
# 4382  2006-11-17   24.50   25.18000   23.50000   24.74000  18358000   FSLR
# 4383  2006-11-17   24.50   25.18000   23.50000   24.74000  18358000   FSLR
#
# [4384 rows x 7 columns]
#         datetime  open  high   low  close   volume ticker
# 0     2024-04-19  8.89  9.03  8.89   8.97  6437400   AMCR
# 1     2024-04-18  8.86  8.91  8.82   8.90  5832100   AMCR
# 2     2024-04-17  8.90  8.93  8.82   8.83  4731500   AMCR
# 3     2024-04-16  8.91  8.94  8.80   8.83  6824400   AMCR
# 4     2024-04-15  9.02  9.08  8.91   8.94  7749000   AMCR
# ...          ...   ...   ...   ...    ...      ...    ...
# 2997  2012-05-21  7.70  7.70  7.70   7.70        0   AMCR
# 2998  2012-05-18  7.70  7.70  7.70   7.70        0   AMCR
# 2999  2012-05-17  7.70  7.70  7.70   7.70        0   AMCR
# 3000  2012-05-16  7.70  7.70  7.70   7.70        0   AMCR
# 3001  2012-05-15  7.70  7.70  7.70   7.70        0   AMCR
#
# [3002 rows x 7 columns]
#         datetime   open   high    low  close  volume ticker
# 0     1996-12-02  24.69  24.69  24.44  24.56   28800    TFX
# 1     1996-11-29  24.81  24.81  24.75  24.75    5200    TFX
# 2     1996-11-27  24.75  24.81  24.62  24.75   10800    TFX
# 3     1996-11-26  24.88  24.88  24.75  24.75   18200    TFX
# 4     1996-11-25  24.88  24.94  24.88  24.88   11800    TFX
# ...          ...    ...    ...    ...    ...     ...    ...
# 4221  1980-03-20   1.53   1.54   1.53   1.53   12600    TFX
# 4222  1980-03-19   1.54   1.55   1.54   1.54   10800    TFX
# 4223  1980-03-18   1.53   1.54   1.47   1.53  106200    TFX
# 4224  1980-03-17   1.53   1.62   1.53   1.53   66600    TFX
# 4225  1980-03-16   1.53   1.62   1.53   1.53   66600    TFX
#
# [4226 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  11.55556  11.55556  11.25000  11.30556   282600     GL
# 1     1996-11-29  11.52778  11.58333  11.50000  11.55556   123300     GL
# 2     1996-11-27  11.41667  11.58333  11.41667  11.47222   738000     GL
# 3     1996-11-26  11.27778  11.41667  11.25000  11.41667  1195200     GL
# 4     1996-11-25  11.30556  11.30556  11.19444  11.27778   598950     GL
# ...          ...       ...       ...       ...       ...      ...    ...
# 4084  1980-10-07   0.00000   2.70370   2.68518   2.68518   423900     GL
# 4085  1980-10-06   0.00000   2.75926   2.74074   2.74074   194400     GL
# 4086  1980-10-03   0.00000   2.81482   2.77778   2.77778    34425     GL
# 4087  1980-10-02   0.00000   2.81482   2.79630   2.79630   106650     GL
# 4088  1980-10-01   0.00000   2.85185   2.83333   2.83333   566325     GL
#
# [4089 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     1996-12-02  12.38  12.38  11.63  11.67   771000    RHI
# 1     1996-11-29  12.29  12.42  12.17  12.42   161100    RHI
# 2     1996-11-27  12.21  12.33  12.17  12.25   415200    RHI
# 3     1996-11-26  12.67  12.67  12.13  12.13  1183800    RHI
# 4     1996-11-25  12.92  12.92  12.58  12.67   762300    RHI
# ...          ...    ...    ...    ...    ...      ...    ...
# 4027  1980-03-19   0.11   0.12   0.11   0.11  1756799    RHI
# 4028  1980-03-18   0.11   0.12   0.11   0.11  1943999    RHI
# 4029  1980-03-17   0.11   0.12   0.11   0.11   359999    RHI
# 4030  1980-03-17   0.11   0.12   0.11   0.11   359999    RHI
# 4031  1980-03-16   0.11   0.12   0.11   0.11   359999    RHI
#
# [4032 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  19.72000  19.91000  19.47000  19.75000  1925200    CAT
# 1     1996-11-29  19.94000  19.97000  19.78000  19.78000   820800    CAT
# 2     1996-11-27  19.59000  19.94000  19.56000  19.91000  2324000    CAT
# 3     1996-11-26  19.97000  20.09000  19.47000  19.53000  3257600    CAT
# 4     1996-11-25  19.88000  20.03000  19.62000  20.03000  2535200    CAT
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-01   6.37500   6.42188   6.37500   6.39062   720800    CAT
# 4996  1977-02-28   6.29688   6.34375   6.28125   6.34375   357600    CAT
# 4997  1977-02-25   6.25000   6.32812   6.23438   6.29688   584800    CAT
# 4998  1977-02-24   6.21875   6.25000   6.21875   6.25000   316000    CAT
# 4999  1977-02-23   6.29688   6.29688   6.20312   6.20312   439200    CAT
#
# [5000 rows x 7 columns]
#      datetime  open   high    low  close  volume ticker
# 0  1970-01-01  63.1  63.13  62.83  62.92  445959   CTSH
# 1  1969-12-31  63.1  63.13  62.83  62.92  445959   CTSH
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  14.53000  14.53000  14.38000  14.44000   884000    UNP
# 1     1996-11-29  14.59000  14.62000  14.50000  14.56000   356800    UNP
# 2     1996-11-27  14.47000  14.62000  14.47000  14.50000  1148000    UNP
# 3     1996-11-26  14.47000  14.84000  14.47000  14.53000  2564400    UNP
# 4     1996-11-25  14.25000  14.47000  14.22000  14.47000  1197200    UNP
# ...          ...       ...       ...       ...       ...      ...    ...
# 4276  1980-01-07   3.02580   3.05207   3.01004   3.01004  1087448    UNP
# 4277  1980-01-04   2.97852   3.02580   2.97852   3.02580  1382510    UNP
# 4278  1980-01-03   2.99428   2.99428   2.94700   2.97327  1453896    UNP
# 4279  1980-01-02   3.01004   3.05207   3.01004   3.01529  1165973    UNP
# 4280  1980-01-02   3.01004   3.05207   3.01004   3.01529  1165973    UNP
#
# [4281 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     2024-04-19  61.15  62.51  60.26  60.71  9857300     ON
# 1     2024-04-18  63.01  63.77  61.51  62.93  8437300     ON
# 2     2024-04-17  65.28  65.87  64.11  64.47  6826300     ON
# 3     2024-04-16  65.40  65.50  64.06  64.72  5214700     ON
# 4     2024-04-15  67.85  67.95  64.88  65.64  7077400     ON
# ...          ...    ...    ...    ...    ...      ...    ...
# 4995  2004-06-16   5.27   5.30   4.83   4.88  4222800     ON
# 4996  2004-06-15   5.25   5.28   5.13   5.25  2001900     ON
# 4997  2004-06-14   5.13   5.18   5.01   5.14  1622100     ON
# 4998  2004-06-10   5.35   5.35   5.08   5.14  1729300     ON
# 4999  2004-06-09   5.35   5.39   5.20   5.28  3165700     ON
#
# [5000 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     1996-12-02  18.38000  18.38000  18.22000  18.25000   200000     GD
# 1     1996-11-29  18.50000  18.50000  18.44000  18.44000    76800     GD
# 2     1996-11-27  18.59000  18.62000  18.44000  18.53000   211600     GD
# 3     1996-11-26  18.66000  18.81000  18.41000  18.59000  1087200     GD
# 4     1996-11-25  18.72000  18.88000  18.59000  18.75000   398800     GD
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1977-03-01   1.41875   1.45625   1.41875   1.45000  1152000     GD
# 4996  1977-02-28   1.39375   1.41250   1.39375   1.41250   328000     GD
# 4997  1977-02-25   1.39688   1.40000   1.37500   1.39375  1848000     GD
# 4998  1977-02-24   1.43125   1.43125   1.39688   1.39688  1000000     GD
# 4999  1977-02-23   1.45938   1.45938   1.43125   1.43125   464000     GD
#
# [5000 rows x 7 columns]
#         datetime   open      high       low     close   volume ticker
# 0     1996-12-02  25.84  25.84000  25.62000  25.69000  2044000    BAC
# 1     1996-11-29  25.88  26.00000  25.84000  25.91000  1583600    BAC
# 2     1996-11-27  25.81  25.97000  25.78000  25.88000  2154800    BAC
# 3     1996-11-26  26.12  26.31000  25.75000  25.78000  4864800    BAC
# 4     1996-11-25  25.59  26.16000  25.56000  26.06000  4559200    BAC
# ...          ...    ...       ...       ...       ...      ...    ...
# 4995  1977-02-25   0.00   1.40625   1.35938   1.35938    77600    BAC
# 4996  1977-02-24   0.00   1.39062   1.34375   1.34375   301600    BAC
# 4997  1977-02-23   0.00   1.42188   1.37500   1.37500   136000    BAC
# 4998  1977-02-22   0.00   1.43750   1.39062   1.39062    54400    BAC
# 4999  1977-02-18   0.00   1.43750   1.39062   1.39062    33600    BAC
#
# [5000 rows x 7 columns]
#         datetime    open    high     low   close   volume ticker
# 0     2024-04-19  125.66  126.15  123.80  125.35  1548500    DFS
# 1     2024-04-18  120.75  125.39  120.55  124.27  2285100    DFS
# 2     2024-04-17  120.91  121.48  119.67  119.89  1746000    DFS
# 3     2024-04-16  121.50  121.50  119.31  119.57   994100    DFS
# 4     2024-04-15  122.74  123.21  120.47  121.31   788900    DFS
# ...          ...     ...     ...     ...     ...      ...    ...
# 4239  2007-06-18   29.32   30.20   29.30   29.93  1591000    DFS
# 4240  2007-06-15   29.50   29.80   28.88   29.08   790100    DFS
# 4241  2007-06-14   28.00   30.50   28.00   28.75  3279100    DFS
# 4242  2007-06-14   28.00   30.50   28.00   28.75  3279100    DFS
# 4243  2007-06-13   28.00   30.50   28.00   28.75  3279100    DFS
#
# [4244 rows x 7 columns]
#         datetime   open   high    low  close    volume ticker
# 0     2010-08-11  10.58  10.67  10.46  10.54   5794076    DHI
# 1     2010-08-10  10.90  10.98  10.72  10.83   4806931    DHI
# 2     2010-08-09  10.90  11.14  10.76  11.06   6151010    DHI
# 3     2010-08-06  10.33  10.66  10.24  10.60   5546459    DHI
# 4     2010-08-05  10.31  10.53  10.28  10.42   4584849    DHI
# ...          ...    ...    ...    ...    ...       ...    ...
# 4566  1992-06-10   1.58   1.63   1.58   1.58    666474    DHI
# 4567  1992-06-09   1.65   1.65   1.58   1.58   1942164    DHI
# 4568  1992-06-08   1.65   1.69   1.65   1.65   1306982    DHI
# 4569  1992-06-05   1.65   1.69   1.65   1.65  14561237    DHI
# 4570  1992-06-04   1.65   1.69   1.65   1.65  14561237    DHI
#
# [4571 rows x 7 columns]
#         datetime       open    high        low      close   volume ticker
# 0     2024-04-19  184.21001  186.62  183.16000  184.12000   609300   VRSN
# 1     2024-04-18  182.14000  184.33  181.64000  182.96001   594400   VRSN
# 2     2024-04-17  182.77000  183.72  181.57001  181.57001   520800   VRSN
# 3     2024-04-16  183.78999  184.37  182.38000  182.63000   556500   VRSN
# 4     2024-04-15  187.02000  187.02  183.12000  183.20000   609500   VRSN
# ...          ...        ...     ...        ...        ...      ...    ...
# 4995  2004-06-16   17.54000   17.91   17.48000   17.56000  1234800   VRSN
# 4996  2004-06-15   17.33000   18.00   17.33000   17.70000  2538400   VRSN
# 4997  2004-06-14   17.43000   17.62   17.03000   17.12000  2016800   VRSN
# 4998  2004-06-10   17.43000   17.72   17.41000   17.61000  1600900   VRSN
# 4999  2004-06-09   17.52000   17.79   17.37000   17.42000  1777400   VRSN
#
# [5000 rows x 7 columns]
#         datetime    open    high     low   close     volume ticker
# 0     2024-04-19  63.790  64.410  62.920  63.400    4815300   FTNT
# 1     2024-04-18  64.770  65.010  63.530  64.030    3087300   FTNT
# 2     2024-04-17  64.890  65.550  64.500  64.660    3278400   FTNT
# 3     2024-04-16  64.620  65.570  64.260  64.480    3015000   FTNT
# 4     2024-04-15  67.080  67.190  64.580  64.730    4911100   FTNT
# ...          ...     ...     ...     ...     ...        ...    ...
# 3623  2009-11-24   1.680   1.705   1.673   1.701    4677000   FTNT
# 3624  2009-11-23   1.706   1.717   1.660   1.690   11858000   FTNT
# 3625  2009-11-20   1.688   1.696   1.606   1.694   11390000   FTNT
# 3626  2009-11-19   1.657   1.712   1.606   1.689   22173000   FTNT
# 3627  2009-11-18   1.700   1.750   1.633   1.662  136704000   FTNT
#
# [3628 rows x 7 columns]
#         datetime   open   high    low  close   volume ticker
# 0     1996-12-02  13.70  13.92  13.70  13.81   559412    HST
# 1     1996-11-29  13.59  13.81  13.59  13.70   511000    HST
# 2     1996-11-27  13.25  13.59  13.25  13.59  1375879    HST
# 3     1996-11-26  13.59  13.59  13.14  13.25  2039113    HST
# 4     1996-11-25  13.48  13.70  13.25  13.59  1304037    HST
#
# [5000 rows x 7 columns]
#         datetime       open       high        low      close  volume ticker
# 0     2024-04-19  227.14000  230.34000  225.64999  226.78000  409100    CRL
# 1     2024-04-18  228.02000  233.72000  223.49001  227.55000  710200    CRL
# 2     2024-04-17  234.39999  234.39999  229.85001  230.09000  499800    CRL
# 3     2024-04-16  235.92000  235.92000  231.39999  232.34000  336000    CRL
# 4     2024-04-15  244.32001  244.41000  234.17000  235.92999  462300    CRL
# ...          ...        ...        ...        ...        ...     ...    ...
# 4995  2004-06-16   45.65000   46.29000   45.55000   46.19000  254100    CRL
# ...
# 3     2024-04-16  368.89001  373.22000  357.06000  357.39001  743200    MOH
# 4     2024-04-15  356.76999  365.63000  355.17001  360.85001  839500    MOH
# ...          ...        ...        ...        ...        ...     ...    ...
# 4995  2004-06-16   24.00000   24.03333   23.90000   24.00000  124650    MOH
# 4996  2004-06-15   23.97333   24.02000   23.81333   23.88000   38250    MOH
# 4997  2004-06-14   24.00000   24.13333   23.73333   23.90667   47550    MOH
# 4998  2004-06-10   24.49333   24.49333   23.92000   24.12667   71550    MOH
# 4999  2004-06-09   24.66667   24.66667   24.48000   24.48667  101400    MOH
#
# [5000 rows x 7 columns]
#         datetime   open   high    low  close  volume ticker
# 0     1996-12-02  28.10  28.10  28.00  28.00    8000    MTB
# 1     1996-11-29  28.00  28.10  28.00  28.10   13000    MTB
# 2     1996-11-27  27.65  27.75  27.65  27.75    6000    MTB
# 3     1996-11-26  27.60  27.60  27.50  27.60   14000    MTB
# 4     1996-11-25  27.40  27.45  27.32  27.45    9000    MTB
# ...          ...    ...    ...    ...    ...     ...    ...
# 4095  1980-03-19   0.54   0.57   0.54   0.54  100000    MTB
# 4096  1980-03-18   0.53   0.56   0.53   0.53   30000    MTB
# 4097  1980-03-17   0.54   0.56   0.54   0.54  104000    MTB
# 4098  1980-03-17   0.54   0.56   0.54   0.54  104000    MTB
# 4099  1980-03-16   0.54   0.56   0.54   0.54  104000    MTB
#
# [4100 rows x 7 columns]
#         datetime   open   high    low  close     volume ticker
# 0     2010-08-11  17.62  17.69  17.23  17.28   23442020   GILD
# 1     2010-08-10  17.80  18.07  17.68  17.89   20017928   GILD
# 2     2010-08-09  18.01  18.02  17.80  17.88   17472342   GILD
# 3     2010-08-06  17.84  17.93  17.65  17.91   22605948   GILD
# 4     2010-08-05  17.53  18.05  17.46  17.86   29825900   GILD
# ...          ...    ...    ...    ...    ...        ...    ...
# 4668  1992-01-27   0.73   0.75   0.70   0.75   10716800   GILD
# 4669  1992-01-24   0.70   0.73   0.67   0.70   12044800   GILD
# 4670  1992-01-23   0.66   0.71   0.63   0.69   38368000   GILD
# 4671  1992-01-22   0.54   0.68   0.54   0.63  168022400   GILD
# 4672  1992-01-22   0.54   0.68   0.54   0.63  168022400   GILD
#
# [4673 rows x 7 columns]
#         datetime   open   high     low  close    volume ticker
# 0     2024-04-19  62.00  62.46  61.725  62.31  13118800   PYPL
# 1     2024-04-18  63.85  64.03  61.950  62.10   9240000   PYPL
# 4191  1980-03-17   0.26   0.28   0.26   0.26   620800    HRL
# 4192  1970-01-01  42.92  42.92  42.86  42.86   518142    HRL
#
# [4193 rows x 7 columns]
#         datetime     open     high      low    close    volume ticker
# 0     2010-08-11  5.76000  5.76000  5.56000  5.57000  15585100    BSX
# 1     2010-08-10  5.82000  5.90000  5.76000  5.84000  12666200    BSX
# 2     2010-08-09  5.81000  5.89000  5.76000  5.88000  11152800    BSX
# 3     2010-08-06  5.65000  5.82000  5.63000  5.80000  15416300    BSX
# 4     2010-08-05  5.71000  5.88000  5.66000  5.69000  26480200    BSX
# ...          ...      ...      ...      ...      ...       ...    ...
# 4589  1992-05-26  4.50000  4.53125  4.37500  4.37500   1727600    BSX
# 4590  1992-05-22  4.40625  4.59375  4.37500  4.53125   3206400    BSX
# 4591  1992-05-21  4.37500  4.37500  4.31250  4.37500   1854000    BSX
# 4592  1992-05-20  4.34375  4.37500  4.31250  4.37500   2560400    BSX
# 4593  1992-05-19  4.25000  4.34375  4.21875  4.28125   7799600    BSX
#
# [4594 rows x 7 columns]
#        datetime    open      high     low   close   volume ticker
# 0    1996-12-02   11.31   11.4600   11.25   11.43  8606000   COST
# 1    1996-11-29   11.25   11.3100   11.25   11.25   109600   COST
# 2    1996-11-27   11.25   11.3100   11.19   11.25  2199200   COST
# 3    1996-11-26   11.01   11.3100   11.01   11.31  6004400   COST
# 4    1996-11-25   10.77   11.0700   10.71   11.07  5463800   COST
# ..          ...     ...       ...     ...     ...      ...    ...
# 783  1993-10-27    9.07    9.0700    8.77    8.83  2498800   COST
# 784  1993-10-26    9.44    9.4400    9.13    9.13  3016600   COST
# 785  1993-10-25    9.20    9.4400    9.13    9.44  2359200   COST
# 786  1993-10-22    9.44    9.6200    9.20    9.20  3009800   COST
# 787  1970-01-01  139.14  139.6575  138.69  138.75   286656   COST
#
# [788 rows x 7 columns]
#         datetime      open      high       low     close   volume ticker
# 0     2010-08-11  17.50667  17.50667  17.00667  17.01333   883950    RJF
# 1     2010-08-10  17.88000  18.04000  17.55333  17.76667   953100    RJF
# 2     2010-08-09  18.38667  18.38667  18.06667  18.11333   762750    RJF
# 3     2010-08-06  18.04000  18.48667  17.92000  18.22667  1023600    RJF
# 4     2010-08-05  18.19333  18.37333  18.10667  18.26000   579150    RJF
# ...          ...       ...       ...       ...       ...      ...    ...
# 4995  1990-10-16   0.57552   0.58040   0.57552   0.57552    10252    RJF
# 4996  1990-10-15   0.58040   0.58040   0.57552   0.58040    15377    RJF
# 4997  1990-10-12   0.58040   0.58040   0.57552   0.57552   263978    RJF
# 4998  1990-10-11   0.57552   0.57552   0.57552   0.57552   517704    RJF
# 4999  1990-10-10   0.58528   0.58528   0.58040   0.58040   187091    RJF
#
# [5000 rows x 7 columns]
#      datetime    open       high     low   close  volume ticker
# 0  1970-01-01  215.66  215.89999  215.66  215.89  217384    MCO
# 1  1969-12-31  215.66  215.89999  215.66  215.89  217384    MCO
#         datetime     open     high      low    close   volume ticker
# 0     1996-12-02  6.55556  6.61111  6.44444  6.50000   893700   VTRS
# ...          ...   ...   ...   ...    ...      ...    ...
# 4224  1980-03-19  2.24  2.27  2.24   2.24  1092000     TT
# 4225  1980-03-18  2.26  2.27  2.23   2.26   882000     TT
# 4226  1980-03-17  2.23  2.30  2.23   2.23   549000     TT
# 4227  1980-03-17  2.23  2.30  2.23   2.23   549000     TT
# 4228  1980-03-16  2.23  2.30  2.23   2.23   549000     TT
#
# [4229 rows x 7 columns]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 83
#      80 five_yrs_more = ticker_days[ticker_days['count'] >= 1825]['ticker']
#      81 df_model = df_model[df_model['ticker'].isin(five_yrs_more)]
# ---> 83 df_model.to_csv(f'data/raw/{datetime.now().strftime("%Y-%m-%d %H:%M:%S")}.csv', index=False)
#
# File c:\Users\18327\Desktop\Python Projects\stock_prediction\.venv\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\18327\Desktop\Python Projects\stock_prediction\.venv\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\18327\Desktop\Python Projects\stock_prediction\.venv\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\18327\Desktop\Python Projects\stock_prediction\.venv\lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\18327\Desktop\Python Projects\stock_prediction\.venv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'data/raw/2024-04-21 02:06:13.csv'

# %%
# List files in the directory
directory = 'data/raw/'
files = os.listdir(directory)

l_all_raw = []
for i in files:
    l_all_raw.append(pd.read_csv(f'{directory}{i}'))

df_out = pd.concat(l_all_raw).drop_duplicates(subset=['datetime', 'ticker']) 
ticker_days = df_out.groupby('ticker')['ticker'].value_counts().reset_index()

# Only include tickers with 5 years or more observations
five_yrs_more = ticker_days[ticker_days['count'] >= 1825]['ticker']
df_out = df_out[df_out['ticker'].isin(five_yrs_more)]

df_out.to_csv('data/data.csv', index_label=False)
df_out
# Out:
# C:\Users\18327\AppData\Local\Temp\ipykernel_8980\3583801672.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   l_all_raw.append(pd.read_csv(f'{directory}{i}'))
# C:\Users\18327\AppData\Local\Temp\ipykernel_8980\3583801672.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   l_all_raw.append(pd.read_csv(f'{directory}{i}'))
#            datetime   open   high    low  close     volume ticker  \
# 0        2024-04-19  24.92  25.01  24.72  24.78   490400.0    NWS
# 1        2024-04-18  24.93  25.37  24.75  24.81   659100.0    NWS
# 2        2024-04-17  25.00  25.09  24.92  24.95   969800.0    NWS
# 3        2024-04-16  24.84  24.99  24.67  24.82   531200.0    NWS
# 4        2024-04-15  25.35  25.49  24.95  25.00   685800.0    NWS
# ...             ...    ...    ...    ...    ...        ...    ...
# 1784206  1980-03-20   2.19   2.23   2.19   2.19   387000.0     TT
# 1784207  1980-03-19   2.24   2.27   2.24   2.24  1092000.0     TT
# 1784208  1980-03-18   2.26   2.27   2.23   2.26   882000.0     TT
# 1784209  1980-03-17   2.23   2.30   2.23   2.23   549000.0     TT
# 1784211  1980-03-16   2.23   2.30   2.23   2.23   549000.0     TT
#
#                     Security             GICS Sector  GICS Sub-Industry  \
# 0        News Corp (Class B)  Communication Services         Publishing
# 1        News Corp (Class B)  Communication Services         Publishing
# 2        News Corp (Class B)  Communication Services         Publishing
# 3        News Corp (Class B)  Communication Services         Publishing
# 4        News Corp (Class B)  Communication Services         Publishing
# ...                      ...                     ...                ...
# 1784206   Trane Technologies             Industrials  Building Products
# 1784207   Trane Technologies             Industrials  Building Products
# 1784208   Trane Technologies             Industrials  Building Products
# 1784209   Trane Technologies             Industrials  Building Products
# 1784211   Trane Technologies             Industrials  Building Products
#
#            Headquarters Location  Date added        CIK  \
# 0        New York City, New York  2015-09-18  1564708.0
# 1        New York City, New York  2015-09-18  1564708.0
# 2        New York City, New York  2015-09-18  1564708.0
# 3        New York City, New York  2015-09-18  1564708.0
# 4        New York City, New York  2015-09-18  1564708.0
# ...                          ...         ...        ...
# 1784206          Dublin, Ireland  2010-11-17  1466258.0
# 1784207          Dublin, Ireland  2010-11-17  1466258.0
# 1784208          Dublin, Ireland  2010-11-17  1466258.0
# 1784209          Dublin, Ireland  2010-11-17  1466258.0
# 1784211          Dublin, Ireland  2010-11-17  1466258.0
#
#                               Founded
# 0        2013 (News Corporation 1980)
# 1        2013 (News Corporation 1980)
# 2        2013 (News Corporation 1980)
# 3        2013 (News Corporation 1980)
# 4        2013 (News Corporation 1980)
# ...                               ...
# 1784206                          1871
# 1784207                          1871
# 1784208                          1871
# 1784209                          1871
# 1784211                          1871
#
# [3484734 rows x 14 columns]
